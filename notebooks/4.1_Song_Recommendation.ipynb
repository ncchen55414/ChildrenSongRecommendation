# %% [markdown]
# ## Load DataFrame

# %%
import pandas as pd
import os

df = pd.read_csv("../data/all.csv")
df.columns                                # 'Artists_Spotify' is from spotify album info
                                          # 'Artists'  is from spotify track info
# Out:
# Index(['Age', 'Album_Name', 'Artist', 'Year', 'Description', 'Age Group',
#        'Album_ID', 'Album_Name_Spotify', 'Artists_Spotify', 'Track_ID', 'ISRC',
#        'Track_Name', 'Artists', 'popularity', 'preview_url', 'image_url',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'lyrics'],
#       dtype='object')

# %%
select_columns = ['Track_ID', 'Track_Name', 'preview_url', 'image_url', 'Artists','Age', 'popularity',
       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
       'time_signature', 'lyrics']

df = df[select_columns]

df['duration_min'] = df['duration_ms']/10**3/60

print (df.shape)
df.head(3)
# Out:
# (19560, 22)
#                  Track_ID           Track_Name  \
# 0  2FPQI1LRwWszttbRG8hknk  Games Monsters Play
# 1  6pOoswwC1lNBI2TapMdaEW   Afraid of the Dark
# 2  2EEwSq98rKwlRWT7sNCLRc  Eensy Weensy Spider
#
#                                          preview_url  \
# 0  https://p.scdn.co/mp3-preview/33cc59cc1836954e...
# 1  https://p.scdn.co/mp3-preview/cf340f0b536edadd...
# 2  https://p.scdn.co/mp3-preview/4cdc12aaeb7da4b7...
#
#                                            image_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273d61faa...
# 1  https://i.scdn.co/image/ab67616d0000b273d61faa...
# 2  https://i.scdn.co/image/ab67616d0000b273d61faa...
#
#                                          Artists  Age  popularity  \
# 0                    ['Herry Monster', 'Grover']    2           5
# 1                              ['Telly Monster']    2           5
# 2  ['Count Von Count', 'The Sesame Street Kids']    2           9
#
#    danceability  energy  key  ...  speechiness  acousticness  \
# 0         0.738   0.544  7.0  ...        0.346         0.212
# 1         0.505   0.525  0.0  ...        0.109         0.355
# 2         0.875   0.338  0.0  ...        0.397         0.762
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0               0.0    0.0937    0.961  144.448     204267.0             4.0
# 1               0.0    0.1000    0.444  127.922     141240.0             4.0
# 2               0.0    0.0992    0.962  116.027      94693.0             4.0
#
#    lyrics  duration_min
# 0     NaN      3.404450
# 1     NaN      2.354000
# 2     NaN      1.578217
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Recommend Songs by KNN

# %% [markdown]
# ### Fit Model

# %%
feature_columns = ['key','mode', 'time_signature', 'duration_min','popularity', 
                   'danceability', 'energy','loudness', 'speechiness',
                   'acousticness', 'instrumentalness', 'liveness', 'valence', 
                   'tempo']
df_audio = df.dropna(subset=feature_columns)
df_audio = df_audio.drop_duplicates() #.reset_index(drop=True)
df_audio = df_audio.astype({'key': 'Int64', 'mode':'Int64', 'time_signature':'Int64'})

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

from sklearn.neighbors import NearestNeighbors

categorical_columns = ['key','mode', 'time_signature']

numeric_columns = ['Age','duration_min','popularity', 'danceability', 'energy','loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

features = ColumnTransformer([
    ('categorical', OneHotEncoder(), categorical_columns),
    ('numeric', 'passthrough', numeric_columns)
])


model = Pipeline([
    ('features', features),
    ('normalize', StandardScaler()),
    ('knn', NearestNeighbors(n_neighbors=10))
])

# %%
model.fit(df_audio);

# %%
model[2]
# Out:
# NearestNeighbors(n_neighbors=10)

# %%
from joblib import dump, load
dump(model[2], '../models/knn_audio_features.joblib')   # dump knn model
dump(df_audio, '../models/songs_df_audio_features.joblib');

# %%
distance, indices = model[2].kneighbors()

# %%
indices[0]    # indices[i] is the list of the nearest kneightbors for item-i
# Out:
# array([ 109, 2800, 2246, 2681,  709, 1830, 4021, 3661,  733,  705],
#       dtype=int64)

# %%
df.iloc[indices[1]][0:3]   # show the first three recommendation for song-1
# Out:
#                     Track_ID                          Track_Name  \
# 2192  1n1AvAiUiOsWsFofNfdkfi                             Wimoweh
# 1841  7b5OsAZ4FTmA0fyZwel0ar  Moon Moon Moon - Alternate Version
# 675   1GbA2OeSw27WxiHArYnRYD              Somebody Come and Play
#
#                                             preview_url  \
# 2192  https://p.scdn.co/mp3-preview/e32bee9384356aba...
# 1841                                                NaN
# 675   https://p.scdn.co/mp3-preview/64f80bd2da135a2a...
#
#                                               image_url  \
# 2192  https://i.scdn.co/image/ab67616d0000b273e4007e...
# 1841  https://i.scdn.co/image/ab67616d0000b273d13fb8...
# 675   https://i.scdn.co/image/ab67616d0000b273f8bae9...
#
#                                      Artists  Age  popularity  danceability  \
# 2192    ['Joanie Leeds and the Nightlights']    2           1         0.657
# 1841             ['The Laurie Berkner Band']    2          25         0.585
# 675   ['Big Bird', 'The Sesame Street Kids']    2          19         0.739
#
#       energy  key  ...  speechiness  acousticness  instrumentalness  liveness  \
# 2192  0.3980  4.0  ...       0.0480         0.538               0.0     0.299
# 1841  0.0778  3.0  ...       0.0673         0.894               0.0     0.126
# 675   0.3150  9.0  ...       0.0547         0.553               0.0     0.247
#
#       valence    tempo  duration_ms  time_signature  \
# 2192    0.467  120.327     189467.0             4.0
# 1841    0.314   95.380     110147.0             4.0
# 675     0.766  140.561     143827.0             4.0
#
#                                                  lyrics  duration_min
# 2192                                                NaN      3.157783
# 1841                                                NaN      1.835783
# 675   Somebody come and play\r\nSomebody come and pl...      2.397117
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Example: Pick up a song using index, and make recommendations.

# %%
knn = load('../models/knn_audio_features.joblib')   # dump knn model
df = load('../models/songs_df_audio_features.joblib')

# %%
distance, indices = knn.kneighbors()

# %%
idx = 2
pd.DataFrame(df.iloc[idx]).T
# Out:
#                  Track_ID           Track_Name  \
# 2  2EEwSq98rKwlRWT7sNCLRc  Eensy Weensy Spider
#
#                                          preview_url  \
# 2  https://p.scdn.co/mp3-preview/4cdc12aaeb7da4b7...
#
#                                            image_url  \
# 2  https://i.scdn.co/image/ab67616d0000b273d61faa...
#
#                                          Artists Age popularity danceability  \
# 2  ['Count Von Count', 'The Sesame Street Kids']   2          9        0.875
#
#   energy key  ... speechiness acousticness instrumentalness liveness valence  \
# 2  0.338   0  ...       0.397        0.762              0.0   0.0992   0.962
#
#      tempo duration_ms time_signature lyrics duration_min
# 2  116.027     94693.0              4    NaN     1.578217
#
# [1 rows x 22 columns]

# %%
idx = 2         

print ("The song picked: ")
display(pd.DataFrame(df.iloc[idx]).T)

recom_idx = indices[idx]

print ("\nRecommendations: ")
df.iloc[recom_idx][0:5]
# Out:
# The song picked:
#                  Track_ID           Track_Name  \
# 2  2EEwSq98rKwlRWT7sNCLRc  Eensy Weensy Spider
#
#                                          preview_url  \
# 2  https://p.scdn.co/mp3-preview/4cdc12aaeb7da4b7...
#
#                                            image_url  \
# 2  https://i.scdn.co/image/ab67616d0000b273d61faa...
#
#                                          Artists Age popularity danceability  \
# 2  ['Count Von Count', 'The Sesame Street Kids']   2          9        0.875
#
#   energy key  ... speechiness acousticness instrumentalness liveness valence  \
# 2  0.338   0  ...       0.397        0.762              0.0   0.0992   0.962
#
#      tempo duration_ms time_signature lyrics duration_min
# 2  116.027     94693.0              4    NaN     1.578217
#
# [1 rows x 22 columns]
# Recommendations:
#                     Track_ID                       Track_Name  \
# 1804  4I7NWDIY2OHJkboYZuCe4c                           I Chew
# 776   1OwaPPFzjieVqN1y3fwmVs            Indoor-Outdoor Voices
# 668   36tMNdeGoMmkhXpUcweAvC  If You're Happy And You Know It
# 745   5rVx5Zo0wrhoK4K9hjZgaT                 This Happy House
# 741   2EUjk7qTInt05cu2V5fVGi              My Baby Is A Genius
#
#                                             preview_url  \
# 1804  https://p.scdn.co/mp3-preview/30d2229bcff8c11a...
# 776   https://p.scdn.co/mp3-preview/da1c52f108beaa63...
# 668                                                 NaN
# 745                                                 NaN
# 741                                                 NaN
#
#                                               image_url  \
# 1804  https://i.scdn.co/image/ab67616d0000b273c6e4b2...
# 776   https://i.scdn.co/image/ab67616d0000b27312cd46...
# 668   https://i.scdn.co/image/ab67616d0000b2736b1fd9...
# 745   https://i.scdn.co/image/ab67616d0000b2734a71aa...
# 741   https://i.scdn.co/image/ab67616d0000b2734a71aa...
#
#                                 Artists  Age  popularity  danceability  \
# 1804                     ['Hullabaloo']    2           3         0.748
# 776                          ['Barney']    2          18         0.867
# 668   ['Music For Little People Choir']    2           9         0.835
# 745                  ['Jessica Harper']    2           1         0.774
# 741                  ['Jessica Harper']    2           1         0.816
#
#       energy  key  ...  speechiness  acousticness  instrumentalness  liveness  \
# 1804   0.467    0  ...        0.299         0.792               0.0    0.1810
# 776    0.484    0  ...        0.331         0.758               0.0    0.0616
# 668    0.387    0  ...        0.360         0.466               0.0    0.1840
# 745    0.486    0  ...        0.426         0.567               0.0    0.0513
# 741    0.396    0  ...        0.463         0.615               0.0    0.1130
#
#       valence    tempo  duration_ms  time_signature  lyrics  duration_min
# 1804    0.963  114.937      69000.0               4     NaN      1.150000
# 776     0.853  145.691     101133.0               4     NaN      1.685550
# 668     0.875  142.259      93960.0               4     NaN      1.566000
# 745     0.971   76.118     155693.0               4     NaN      2.594883
# 741     0.649  139.999     172160.0               4     NaN      2.869333
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Write the Recommender as a python class

# %%
class SongRecommender():
    def __init__(self):
        self.df = None
        self.model = None
        self.distance = None
        self.indices = None
        
    def load_data(self, option='audio'):
        if option == 'audio':
            self.df = load('../models/songs_df_audio_features.joblib')
            self.model = load('../models/knn_audio_features.joblib')  
            knn = self.model
            self.distance, self.indices = knn.kneighbors()
    
    def make_recommendation(self, idx, num=5):
        num = min(num, 20)
        
        print ("Song Selected: ")
        display(self.df.iloc[[idx]])
        return self.df.iloc[self.indices[idx]][0:num]

# %%
recom = SongRecommender()

# %%
recom.load_data()

# %%
recom.make_recommendation(3)
# Out:
# Song Selected:
#                  Track_ID                             Track_Name  \
# 3  0FG1XPQfLWKzJbayikwucU  Be Kind to Your Neighborhood Monsters
#
#                                          preview_url  \
# 3  https://p.scdn.co/mp3-preview/9e0ab5d8ccc7d5cb...
#
#                                            image_url     Artists  Age  \
# 3  https://i.scdn.co/image/ab67616d0000b273d61faa...  ['Grover']    2
#
#    popularity  danceability  energy  key  ...  speechiness  acousticness  \
# 3           5         0.593   0.508   10  ...        0.335         0.702
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 3               0.0     0.675    0.673  127.663     172200.0               4
#
#    lyrics  duration_min
# 3     NaN          2.87
#
# [1 rows x 22 columns]
#                     Track_ID                             Track_Name  \
# 114   3YG9DzaY0Tmr5o9WdpDofO  Be Kind to Your Neighborhood Monsters
# 3130  1z8039cpLZ8bMoKSCpoGZr                              Hey Manny
# 612   1GfgRhQYFserXZ45gCByLq                               Me Dance
# 879   4ELuHk1S0xpMIgGVOsX8me            Fuzzy and Blue (And Orange)
# 6564  0VRJtAPuTBrYTfAjVp7HD9                       Whispering Bells
#
#                                             preview_url  \
# 114   https://p.scdn.co/mp3-preview/9e0ab5d8ccc7d5cb...
# 3130                                                NaN
# 612   https://p.scdn.co/mp3-preview/16624a9566bd312b...
# 879   https://p.scdn.co/mp3-preview/dc987d74b9a3b339...
# 6564                                                NaN
#
#                                               image_url  \
# 114   https://i.scdn.co/image/ab67616d0000b2732d27e5...
# 3130  https://i.scdn.co/image/ab67616d0000b2738e7b5f...
# 612   https://i.scdn.co/image/ab67616d0000b273392a05...
# 879   https://i.scdn.co/image/ab67616d0000b273256d67...
# 6564  https://i.scdn.co/image/ab67616d0000b27320c7ae...
#
#                                                 Artists  Age  popularity  \
# 114                                          ['Grover']    2           5
# 3130                            ['Manny and the Tools']    3           9
# 612                                   ['Yolanda Adams']    2           8
# 879   ['Grover', 'Cookie Monster', 'Herry Monster', ...    2          39
# 6564                                ['The Del-Vikings']    8           0
#
#       danceability  energy  key  ...  speechiness  acousticness  \
# 114          0.593   0.508   10  ...       0.3350         0.702
# 3130         0.610   0.668   10  ...       0.0713         0.705
# 612          0.774   0.918   10  ...       0.2280         0.538
# 879          0.561   0.594   10  ...       0.4120         0.523
# 6564         0.532   0.648   10  ...       0.0760         0.740
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 114           0.000000     0.675    0.673  127.663     172200.0
# 3130          0.000000     0.567    0.896  136.669     105960.0
# 612           0.000000     0.702    0.785  129.038     113027.0
# 879           0.000000     0.347    0.585  137.665     153040.0
# 6564          0.000454     0.487    0.644  127.193     146173.0
#
#       time_signature                                             lyrics  \
# 114                4                                                NaN
# 3130               4                                                NaN
# 612                4                                                NaN
# 879                4                                                NaN
# 6564               4  Whispering bells\r\nBeen so long\r\nWhispering...
#
#       duration_min
# 114       2.870000
# 3130      1.766000
# 612       1.883783
# 879       2.550667
# 6564      2.436217
#
# [5 rows x 22 columns]
